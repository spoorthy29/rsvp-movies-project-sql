# %% [markdown]
# <a href="https://colab.research.google.com/github/spoorthy29/rsvp-movies-project-sql/blob/main/Copy_of_Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data preparation and cleaning

# %% [markdown]
# #load and inspect the data

# %%
import pandas as pd
data=pd.read_csv("/content/index.csv")
data.head()
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#      coffee_name
# 0          Latte
# 1  Hot Chocolate
# 2  Hot Chocolate
# 3      Americano
# 4          Latte

# %%
data.isnull().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %%
data['card'].fillna(data['card'].mode()[0] ,inplace=True)
# Out:
# <ipython-input-4-e8a1dcd7fff4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['card'].fillna(data['card'].mode()[0] ,inplace=True)

# %%
data.drop('date',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-ff4b21a0a12b> in <cell line: 1>()
# ----> 1 data.drop('date',axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
data
# Out:
#                      datetime cash_type                 card  money  \
# 0     2024-03-01 10:15:50.520      card  ANON-0000-0000-0001  38.70
# 1     2024-03-01 12:19:22.539      card  ANON-0000-0000-0002  38.70
# 2     2024-03-01 12:20:18.089      card  ANON-0000-0000-0002  38.70
# 3     2024-03-01 13:46:33.006      card  ANON-0000-0000-0003  28.90
# 4     2024-03-01 13:48:14.626      card  ANON-0000-0000-0004  38.70
# ...                       ...       ...                  ...    ...
# 1128  2024-07-31 20:53:35.077      card  ANON-0000-0000-0443  23.02
# 1129  2024-07-31 20:59:25.013      card  ANON-0000-0000-0040  27.92
# 1130  2024-07-31 21:26:26.000      card  ANON-0000-0000-0444  32.82
# 1131  2024-07-31 21:54:11.824      card  ANON-0000-0000-0445  32.82
# 1132  2024-07-31 21:55:16.570      card  ANON-0000-0000-0446  32.82
#
#               coffee_name
# 0                   Latte
# 1           Hot Chocolate
# 2           Hot Chocolate
# 3               Americano
# ...

# %%
data.isnull().sum()
# Out:
# datetime       0
# cash_type      0
# card           0
# money          0
# coffee_name    0
# dtype: int64
